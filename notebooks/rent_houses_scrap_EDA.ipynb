# %%
import pandas as pd

# %%
df_houses = pd.read_csv('../data/df_houses_full_cleanned.csv')

# %%
df_houses.shape
# Out:
# (1703, 11)

# %%
df_houses.describe(include='all').T
# Out:
#                   count unique                    top  freq            mean  \
# Unnamed: 0       1703.0    NaN                    NaN   NaN      863.012918
# house_id         1703.0    NaN                    NaN   NaN  1655260.864357
# scrapy_datetime    1703   1703  2021/05/13 - 12:51:30     1             NaN
# city               1703     11                 Berlin   614             NaN
# street             1703    693          Wielandstraße    91             NaN
# size             1703.0    NaN                    NaN   NaN       55.994262
# pets               1670      3       Pets not allowed  1101             NaN
# montly_rent      1703.0    NaN                    NaN   NaN      1583.21374
# deposit_value    1703.0    NaN                    NaN   NaN     1610.920728
# lat              1703.0    NaN                    NaN   NaN       51.344549
# long             1703.0    NaN                    NaN   NaN       10.685682
#
# ...
